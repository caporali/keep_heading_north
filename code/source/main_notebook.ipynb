# %% [markdown]
# ## Tested seeds

# %%
seed, bound = 912, 3
seed, bound = 239, 3
seed, bound = 59, 4
seed, bound = 17, 4
seed, bound = 921, 5
seed, bound = 230, 5

# %% [markdown]
# ## Game

# %%
import sys
sys.dont_write_bytecode = True

import main
main.notebook = True

seed, bound = -1, -1
# uncomment to play on already tested map ((-1, -1) gives a random game)
# seed, bound = 912, 3
main.main(seed = seed, bound = bound)
# Out:
#      _                  _             _ _                        _   _
#     | |_ ___ ___ ___   | |_ ___ ___ _| |_|___ ___    ___ ___ ___| |_| |_
#     | '_| -_| -_| . |  |   | -_| .'| . | |   | . |  |   | . |  _|  _|   |
#     |_,_|___|___|  _|  |_|_|___|__,|___|_|_|_|_  |  |_|_|___|_| |_| |_|_|
#                 |_|                          |___|
#
#
# Welcome to "keep heading north", a reinvented text-based game in 2023.
#
# -----------------------------------------------------------------------------
#
# Game settings
#     - Select map size (from 2 to 5): 3
#     - Select a gamemode (balanced/survivor/explorer):
#     - Select a difficulty (easy/hard):
#       The maximum available score is set to 1000.
#
#                     -------------------------------------
#
# You wake up in a gloomy cave.
# You can't remember how you ended up here. You just feel that it is not safe.
# You are extremely curious and ready to fight.
# ...
