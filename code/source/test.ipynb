# %% [markdown]
# ## Main

# %%
import sys
sys.dont_write_bytecode = True
from functions.map import *
from functions.tk_extension import *

# %% [markdown]
# ## Test

# %%
m = map()
map_filename = "map_0"
m.load("maps/" + map_filename + ".map")
m.draw(filename = "maps/" + map_filename + ".png",
	seed = 0, caption = [0, 0, 0],
	figure_size = 15)

# %%
m = map()
map_filename = "map_1"
m.load("maps/" + map_filename + ".map")
m.draw(filename = "maps/" + map_filename + ".png",
	seed = 0, caption = [0, 0, 0],
	figure_size = 15)

# %%
seed = random.randint(0, 1000)
random.seed(seed)
k = 3
m = map(generate = k)
map_filename = "map_gen_0"
m.draw(filename = "maps/" + map_filename + ".png",
	seed = seed, caption = [0, 0, 0],
	figure_size = 15)
m.save("maps/" + map_filename + ".map")

# load from last save
m = map()
m.load("maps/" + map_filename + ".map")
# fig = m.draw(seed = 0, caption = [0, 0, 0],
# 	figure_size = 15)

# %% [markdown]
# ## TODO
# - reinforcement
